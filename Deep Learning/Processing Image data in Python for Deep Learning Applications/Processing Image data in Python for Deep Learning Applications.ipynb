# %% [markdown]
# **Topics:**
#
#
#
# *   Reading an image file and converting it to a numpy array
# *   Resizing an image
# *   RGB to Grayscale conversion

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('/Users/tushark/Downloads/1223720-rashmika-mandanna.webp')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1000, 1280, 3)

# %%
print(img)
# Out:
# [[[252 251 252]
#   [252 251 252]
#   [252 251 252]
#   ...
#   [250 253 249]
#   [250 253 249]
#   [250 253 249]]
#
#  [[252 251 252]
#   [252 251 252]
#   [252 251 252]
#   ...
#   [250 253 249]
#   [250 253 249]
#   [250 253 249]]
#
#  [[252 251 252]
#   [252 251 252]
#   [252 251 252]
#   ...
#   [250 253 249]
#   [250 253 249]
#   [250 253 249]]
#
#  ...
#
#  [[246 246 246]
#   [246 246 246]
#   [246 246 246]
#   ...
#   [253 250 254]
#   [253 250 254]
#   [253 250 254]]
#
#  [[246 246 246]
#   [246 246 246]
#   [246 246 246]
#   ...
#   [253 250 254]
#   [253 250 254]
#   [253 250 254]]
#
#  [[246 246 246]
#   [246 246 246]
#   [246 246 246]
#   ...
#   [253 250 254]
#   [253 250 254]
#   [253 250 254]]]

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL  import  Image

# %%
img = Image.open('/Users/tushark/Downloads/1223720-rashmika-mandanna.webp')
img_resized = img.resize((200, 200))

# %%
img_resized.save('rashmika_mandanna_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('/Users/tushark/Downloads/1223720-rashmika-mandanna.webp')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (1000, 1280, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('/Users/tushark/Downloads/1223720-rashmika-mandanna.webp')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1000, 1280, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1000, 1280)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
# displaying the image
def cv2_imshow(grayscale_image):
    pass
cv2_imshow(grayscale_image)

# %%
# saving the grayscale image
cv2.imwrite('rashmika_mandanna_image.jpg', grayscale_image)
# Out:
# True
