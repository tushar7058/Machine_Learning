# %%
import pandas as pd

df = pd.DataFrame({
    "name":["wscube","cow ","cat ","Dog ","Black"]
})
df
# Out:
#      name
# 0  wscube
# 1    cow
# 2    cat
# 3    Dog
# 4   Black

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() # used for encoding nominal
df["en_name"]=le.fit_transform(df["name"])

# %%
df
# Out:
#      name  en_name
# 0  wscube        4
# 1    cow         3
# 2    cat         2
# 3    Dog         1
# 4   Black        0

# %%
data = pd.read_csv("/Users/tushark/Downloads/cars_clus.csv")
data.head(2)
# Out:
#   manufact    model   sales  resale  type  price  engine_s  horsepow  \
# 0    Acura  Integra  16.919  16.360     0   21.5       1.8       140
# 1    Acura       TL  39.384  19.875     0   28.4       3.2       225
#
#    wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales  partition
# 0     101.2   67.3   172.4     2.639      13.2  28.0    2.828          0
# 1     108.1   70.3   192.9     3.517      17.2  25.0    3.673          0

# %%
data["type"].unique()
# Out:
# array([0, 1])

# %%
la =LabelEncoder()
la.fit(data["type"])
# Out:
# LabelEncoder()

# %%
data["type"]=la.transform(data["type"])
