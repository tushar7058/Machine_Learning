# %%
import  matplotlib.pyplot as plt
import numpy as np
import  random

# %%
x= np.random.randint(10,60,(30))
print(x)
# Out:
# [15 14 33 37 31 57 10 54 25 21 27 44 34 29 56 57 11 54 56 24 49 31 50 56
#  43 48 25 30 10 44]

# %%
num = [15, 14, 33, 37, 31, 57, 10 ,54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31 ,50, 56,43 ,48, 25, 30, 10, 44]
l=[10,20,30,40,50]
plt.hist(num ,color='r',bins=l,edgecolor='black',rwidth=5)
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y",)
plt.show()

# %%
num = [15, 14, 33, 37, 31, 57, 10 ,54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31 ,50, 56,43 ,48, 25, 30, 10, 44]
l=[10,20,30,40,50]
plt.hist(num ,"auto",(0,150),edgecolor='black')
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y",)
plt.show()

# %%
num = [15, 14, 33, 37, 31, 57, 10 ,54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31 ,50, 56,43 ,48, 25, 30, 10, 44]
# l=[10,20,30,40,50]
plt.hist(num ,"auto",(0,150),edgecolor='black',cumulative=-1)
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y",)
plt.show()

# %%
plt.show()
num = [15, 14, 33, 37, 31, 57, 10, 54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31, 50, 56, 43, 48, 25, 30,
       10, 44]
# l=[10,20,30,40,50]
plt.hist(num, "auto", (0, 150), edgecolor='black',align="mid")
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y", )
plt.show()

# %%
plt.show()
num = [15, 14, 33, 37, 31, 57, 10, 54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31, 50, 56, 43, 48, 25, 30,
       10, 44]
# l=[10,20,30,40,50]
plt.hist(num, "auto", (0, 150), edgecolor='black',histtype="step")
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y", )
plt.show()

# %%
num = [15, 14, 33, 37, 31, 57, 10, 54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31, 50, 56, 43, 48, 25, 30,
       10, 44]
# l=[10,20,30,40,50]
plt.hist(num, "auto", (0, 150), edgecolor='black',histtype="stepfilled")
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y", )
plt.show()

# %%
plt.show()

num = [15, 14, 33, 37, 31, 57, 10, 54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31, 50, 56, 43, 48, 25, 30,
       10, 44]
# l=[10,20,30,40,50]
plt.hist(num, "auto", (0, 150), edgecolor='black', histtype="bar")
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y", )
plt.show()

# %%
num = [15, 14, 33, 37, 31, 57, 10, 54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31, 50, 56, 43, 48, 25, 30,
       10, 44]
# l=[10,20,30,40,50]
plt.hist(num, "auto", (0, 150), edgecolor='black', orientation="horizontal")
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y", )
plt.show()

# %%
num = [15, 14, 33, 37, 31, 57, 10, 54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31, 50, 56, 43, 48, 25, 30,
       10, 44]
l=[10,20,30,40,50]
plt.hist(num, "auto", (0, 150), edgecolor='black',log=True,)
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y", )
plt.show()

# %%
num = [15, 14, 33, 37, 31, 57, 10 ,54, 25, 21, 27, 44, 34, 29, 56, 57, 11, 54, 56, 24, 49, 31 ,50, 56,43 ,48, 25, 30, 10, 44]
l=[10,20,30,40,50]
plt.hist(num ,color='r',bins=l,edgecolor='black',label="python")
plt.title("numbers")
plt.xlabel("num of x")
plt.ylabel("num of y",)
plt.axvline(35,color="green",label="line")
plt.legend()
plt.show()
